# %% [markdown]
# <a href="https://colab.research.google.com/github/LoaoneSeleka/Cape-Town-Airbnb-Exploratory-Analysis-Project/blob/main/Cape%20Town%20Data%20Analysis%20Using%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-7eb8c2f2-4373-47cf-b12b-ce5bb513a479" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eb8c2f2-4373-47cf-b12b-ce5bb513a479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['listings.csv']),sep = ';',encoding= 'unicode_escape',on_bad_lines='skip', engine ='python')

# %%
df.head(10)
# Out:
#           id                                               name    host_id  \
# 0   736534.0      Enjoy a Private Room in Chartfield Guesthouse  3007248.0
# 1     3191.0                            Malleson Garden Cottage     3754.0
# 2  1625734.0  Fabulous Villa, Large Entertainment Area Patio...  8643899.0
# 3   742345.0                     Room with a View - Green Point  3886732.0
# 4  1626659.0                Big Bay La Paloma - 2 bedroom suite  5646468.0
# 5    15007.0                                   Blaauwberg House    59072.0
# 6   751120.0        Open plan family home with pool and cottage  2210731.0
# 7    15077.0                  Top relaxed beach living in style    59342.0
# 8    15199.0                            Self catering apartment    59694.0
# 9  1642108.0                        Guinea Fowl House Kommetjie  8718245.0
#
#           host_name neighbourhood   latitude  longitude        room_type  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', ' price ', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm'],
#       dtype='object')
